# %%
import seaborn as sns
import metapack as mp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display 

# %matplotlib inline
sns.set_context('notebook')
mp.jupyter.init()


# %load_ext autoreload
# %autoreload 2

# %%
import rowgenerators as rg
bcg = rg.geoframe('census://2018/5/CA/block')
bcg['centroid'] = bcg.centroid

# %%
bcg['intptlat'] = bcg.intptlat10.astype('float')
bcg['intptlon'] = bcg.intptlon10.astype('float')

# %%
bcg.head().T
# Out:
#                                                             0  \
# statefp10                                                  06
# countyfp10                                                061
# tractce10                                              021401
# blockce10                                                1023
# geoid10                                       060610214011023
# name10                                             Block 1023
# mtfcc10                                                 G5040
# ur10                                                        U
# uace10                                                  77068
# uatype                                                      U
# funcstat10                                                  S
# aland10                                                 15358
# awater10                                                    0
# intptlat10                                        +38.8925477
# ...

# %%
from geoid.tiger import TigerGeoid
from geoid.census import Block

bcg['geoid'] = bcg.geoid10.apply(lambda v: str(Block.parse(v).as_acs()))

# %%
t = bcg[bcg.countyfp10 == '073']
t[['geoid','intptlat','intptlon','centroid']]\
    .rename(columns={ 'centroid':'geometry'})\
    .to_csv('../data/census_blocks.csv', index=False)

# %%
bcg
# Out:
#        statefp10 countyfp10 tractce10 blockce10          geoid10      name10  \
# 0             06        061    021401      1023  060610214011023  Block 1023
# 1             06        061    021401      2023  060610214012023  Block 2023
# 2             06        061    021401      1020  060610214011020  Block 1020
# 3             06        061    021401      2019  060610214012019  Block 2019
# 4             06        061    021123      3003  060610211233003  Block 3003
# ...          ...        ...       ...       ...              ...         ...
# 710140        06        065    044926      1012  060650449261012  Block 1012
# 710141        06        065    044925      2012  060650449252012  Block 2012
# 710142        06        065    044907      1001  060650449071001  Block 1001
# 710143        06        065    044907      1003  060650449071003  Block 1003
# 710144        06        065    044926      1014  060650449261014  Block 1014
#
# ...
