# %%
import seaborn as sns
import metapack as mp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display 

# %matplotlib inline
sns.set_context('notebook')
mp.jupyter.init()

import warnings
warnings.filterwarnings("ignore")

# %%
#pkg = mp.jupyter.open_package()
pkg = mp.jupyter.open_source_package()
pkg
# Out:
# `sandiegodata.org-passonsoped-1.1.1` Last Update: 2020-09-27T18:08:37
#
# __
#
#
#
#
#
#
# ## Contacts
#
# * **Wrangler** [Eric Busboom](mailto:eric@civicknowledge.com), [Civic Knowledge](http://civicknowledge.com)
#
# ## Resources
#
# * ** [sdcrime_2016](data/2016.csv)**. San Diego crime suspects and victims, 2016, unprocessed
# * ** [sdcrime_2017](data/2017.csv)**. San Diego crime suspects and victims, 2017
# * ** [sdcrime_2018](data/2018.csv)**. San Diego crime suspects and victims, 2018
# * ** [sdcrime_2019](data/2019.csv)**. San Diego crime suspects and victims, 2019
# * ** [sdcrime_2020](data/2020.csv)**. San Diego crime suspects and victims, 2020
# * ** [ucrcodes](data/CodeUCRLookup.csv)**. UCR codes and detailed descriptions
# * ** [sdcrime_16_20](notebooks/process.ipynb)**. San Diego crime suspects and victims, 2016 to 2020, with extra geographic information
#
# ## References
# <ul><li> <strong>census_blocks</string>, <em>data/census_blocks.csv</em>. Census 2010 blocks, converted to ACS geoids, with centroid position</li><ul>

# %%
df = pkg.resource('sdcrime_2016').dataframe()
df.head().T
# Out:
#                                                                 0  \
# pk                                                       12144871
# activityNumber                                         '01600014'
# activityType                                           CRIME CASE
# activityDate                                  2016-01-01 00:00:00
# year                                                         2016
# agency                                              NATIONAL CITY
# violationSection                                            10851
# violationType                                                  VC
# chargeDescription  TAKE VEHICLE W/O OWNER'S CONSENT/VEHICLE THEFT
# chargeLevel                                                FELONY
# codeUcr                                                       7A0
# CrimeCategory                                       Vehicle Theft
# highestChargeFlag                                               1
# PersonRole                                                 VICTIM
# Race                                                        OTHER
# Age                                                           NaN
# sex                                                        FEMALE
# role                                                     INCIDENT
# zipCode                                                     91950
# censusBlock                                               '02000'
# censusTract                                              '022000'
# City                                                NATIONAL CITY
#
#                                       1                    2  \
# pk                             12127327             12278698
# activityNumber               '16000042'           '16005661'
# activityType                 CRIME CASE           CRIME CASE
# activityDate        2016-01-01 00:00:00  2016-01-01 00:00:00
# year                               2016                 2016
# agency                        SAN DIEGO            SAN DIEGO
# violationSection                    459                  488
# violationType                        PC                   PC
# chargeDescription  BURGLARY/UNSPECIFIED          PETTY THEFT
# chargeLevel                      FELONY          MISDEMEANOR
# codeUcr                             5A6                  6DG
# CrimeCategory          Non Res Burglary       Larceny < $400
# highestChargeFlag                     1                    1
# PersonRole                          NaN              SUSPECT
# Race                                NaN                WHITE
# Age                                 NaN                   28
# sex                                 NaN                 MALE
# role                           INCIDENT             INCIDENT
# zipCode                           92109                92115
# censusBlock                     '20000'              '20230'
# censusTract                    '007907'             '002902'
# City                          SAN DIEGO            SAN DIEGO
#
#                                      3  \
# pk                            12278698
# activityNumber              '16005661'
# activityType                CRIME CASE
# activityDate       2016-01-01 00:00:00
# year                              2016
# agency                       SAN DIEGO
# violationSection                   488
# violationType                       PC
# chargeDescription          PETTY THEFT
# chargeLevel                MISDEMEANOR
# codeUcr                            6DG
# CrimeCategory           Larceny < $400
# highestChargeFlag                    1
# PersonRole              VICTIM/WITNESS
# Race                          HISPANIC
# Age                                 74
# sex                               MALE
# role                          INCIDENT
# zipCode                          92115
# censusBlock                    '20230'
# censusTract                   '002902'
# City                         SAN DIEGO
#
#                                                             4
# pk                                                   12364997
# activityNumber                                     '16008822'
# activityType                                       CRIME CASE
# activityDate                              2016-01-01 00:00:00
# year                                                     2016
# agency                                              SAN DIEGO
# violationSection                                       487(A)
# violationType                                              PC
# chargeDescription  GRAND THEFT:MONEY/LABOR/PROPERTY OVER $950
# chargeLevel                                            FELONY
# codeUcr                                                   6AE
# CrimeCategory                                 Larceny >= $400
# highestChargeFlag                                           1
# PersonRole                                     VICTIM/WITNESS
# Race                                                    WHITE
# Age                                                        70
# sex                                                      MALE
# role                                                 INCIDENT
# zipCode                                                 92109
# censusBlock                                           '20120'
# censusTract                                          '007905'
# City                                                SAN DIEGO

# %%
from geoid.acs import Tract, Block, AcsGeoid

def mk_tract_geoid(v):

    if v is None or v is np.nan:
        return None
    else:
        return str(Tract(6, 73, int(v) ))

def mk_bg_geoid(r):

    if r.censusTract is None or r.censusTract is np.nan or r.censusBlock is None or r.censusBlock is np.nan:
        return None
    else:
        return str(Block(6, 73, int(r.censusTract), int(r.censusBlock) ))

for r in pkg.resources():
    if 'crime' in r.name:
        break
        
print(r.name)
# Out:
# sdcrime_2016

# %%
df = pd.concat(frames)

# %%
blks = pkg.reference('census_blocks').dataframe().rename(columns={'geoid':'block_geoid'})
blks.head()

# %%
df = df.merge(blks, on='block_geoid')

# %%
18/8
# Out:
# 2.25

# %%
df[df.agency == 'SAN DIEGO'].head().T
# Out:
#                                                            180   \
# pk                                                     14270022
# activityNumber                                       '17009609'
# activityType                                         CRIME CASE
# activityDate                                2016-11-01 00:00:00
# year                                                       2016
# agency                                                SAN DIEGO
# violationSection                                      261(A)(2)
# violationType                                                PC
# chargeDescription                         RAPE: FORCE/FEAR/ETC.
# chargeLevel                                              FELONY
# codeUcr                                                     2B0
# CrimeCategory                                              Rape
# highestChargeFlag                                             1
# PersonRole                                              SUSPECT
# Race                                                      OTHER
# Age                                                         NaN
# sex                                                        MALE
# role                                                   INCIDENT
# zipCode                                                   91942
# censusBlock                                               02000
# censusTract                                              014805
# City                                                    LA MESA
# tract_geoid                                  14000US06073014805
# block_geoid                              10100US060730148052000
# intptlat                                                32.7767
# intptlon                                               -117.036
# geometry           POINT (-117.0361197847325 32.77669757486128)
#
#                                                            181   \
# pk                                                     14270022
# activityNumber                                       '17009609'
# activityType                                         CRIME CASE
# activityDate                                2016-11-01 00:00:00
# year                                                       2016
# agency                                                SAN DIEGO
# violationSection                                      261(A)(2)
# violationType                                                PC
# chargeDescription                         RAPE: FORCE/FEAR/ETC.
# chargeLevel                                              FELONY
# codeUcr                                                     2B0
# CrimeCategory                                              Rape
# highestChargeFlag                                             1
# PersonRole                                       VICTIM/WITNESS
# Race                                                      WHITE
# Age                                                          19
# sex                                                      FEMALE
# role                                                   INCIDENT
# zipCode                                                   91942
# censusBlock                                               02000
# censusTract                                              014805
# City                                                    LA MESA
# tract_geoid                                  14000US06073014805
# block_geoid                              10100US060730148052000
# intptlat                                                32.7767
# intptlon                                               -117.036
# geometry           POINT (-117.0361197847325 32.77669757486128)
#
#                                                            1593  \
# pk                                                     13318299
# activityNumber                                       '16041437'
# activityType                                         CRIME CASE
# activityDate                                2016-10-08 06:45:00
# year                                                       2016
# agency                                                SAN DIEGO
# violationSection                                         273.5A
# violationType                                                PC
# chargeDescription  INFLICT CORPORAL INJURY ON SPOUSE/COHABITANT
# chargeLevel                                              FELONY
# codeUcr                                                     4E0
# CrimeCategory                                    Simple Assault
# highestChargeFlag                                             1
# PersonRole                                              SUSPECT
# Race                                                   HISPANIC
# Age                                                          37
# sex                                                        MALE
# role                                                   INCIDENT
# zipCode                                                   91911
# censusBlock                                               01040
# censusTract                                              013310
# City                                                CHULA VISTA
# tract_geoid                                  14000US06073013310
# block_geoid                              10100US060730133101040
# intptlat                                                32.6203
# intptlon                                               -117.023
# geometry           POINT (-117.0228822308434 32.62033910734949)
#
#                                                            1594  \
# pk                                                     13318299
# activityNumber                                       '16041437'
# activityType                                         CRIME CASE
# activityDate                                2016-10-08 06:45:00
# year                                                       2016
# agency                                                SAN DIEGO
# violationSection                                         273.5A
# violationType                                                PC
# chargeDescription  INFLICT CORPORAL INJURY ON SPOUSE/COHABITANT
# chargeLevel                                              FELONY
# codeUcr                                                     4E0
# CrimeCategory                                    Simple Assault
# highestChargeFlag                                             1
# PersonRole                                               VICTIM
# Race                                                   HISPANIC
# Age                                                          34
# sex                                                      FEMALE
# role                                                   INCIDENT
# zipCode                                                   91911
# censusBlock                                               01040
# censusTract                                              013310
# City                                                CHULA VISTA
# tract_geoid                                  14000US06073013310
# block_geoid                              10100US060730133101040
# intptlat                                                32.6203
# intptlon                                               -117.023
# geometry           POINT (-117.0228822308434 32.62033910734949)
#
#                                                            2177
# pk                                                     12482482
# activityNumber                                       '16004394'
# activityType                                         CRIME CASE
# activityDate                                2016-01-31 00:00:00
# year                                                       2016
# agency                                                SAN DIEGO
# violationSection                                             69
# violationType                                                PC
# chargeDescription             OBSTRUCT/RESIST EXECUTIVE OFFICER
# chargeLevel                                              FELONY
# codeUcr                                                     4E0
# CrimeCategory                                    Simple Assault
# highestChargeFlag                                             1
# PersonRole                                              SUSPECT
# Race                                                   HISPANIC
# Age                                                          52
# sex                                                        MALE
# role                                                   INCIDENT
# zipCode                                                   91950
# censusBlock                                               02005
# censusTract                                              011902
# City                                              NATIONAL CITY
# tract_geoid                                  14000US06073011902
# block_geoid                              10100US060730119022005
# intptlat                                                32.6856
# intptlon                                                -117.08
# geometry           POINT (-117.0800916526166 32.68555759849126)

# %%
df['activityDate'] = pd.to_datetime(df['activityDate'])
df['year'] = df.activityDate.dt.year
# Out:
# 0        2016
# 1        2016
# 2        2016
# 3        2016
# 4        2016
#          ...
# 78744    2016
# 78745    2016
# 78746    2016
# 78747    2016
# 78748    2016
# Name: activityDate, Length: 78749, dtype: int64
